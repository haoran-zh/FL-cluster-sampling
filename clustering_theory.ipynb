# %%
import random
from clustering.utils.constants import *
from clustering.utils.utils import *
from clustering.server import Server
np.random.seed(random_seed)
torch.manual_seed(random_seed)
random.seed(random_seed)

# %%
class_set_list = [[1,2],[3,4],[5,6],[7,8],[9,0]]
tasks_data_info, tasks_data_idx = get_experiment_data(class_set_list)
# Out:
# /Users/alberty/Desktop/18786/FL-cluster-sampling/utility/dataset.py:101: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels = torch.tensor(dataset.targets)

# %%
# example single run
cluster_reqirements = {
    "method": "non_cosine",
    "data_type": "true_labels",
    "dim_method": "theory",
    "cluster_method": "kmeans"
}
cluster_reqirements = tuple(v for _,v in cluster_reqirements.items())
server_cluster = Server(tasks_data_info, 
                        tasks_data_idx, 
                        cluster_requirements = cluster_reqirements)
server_cluster.FL_training(sampling_method='cluster', rounds=10)
# Out:
#  90%|█████████ | 9/10 [00:10<00:01,  1.11s/it]
# Silhouette score: 1.0
# [[1 2]
#  [3 4]
#  [3 4]
#  [7 8]
#  [5 6]
#  [3 4]
#  [3 4]
#  [7 8]
#  [1 2]
#  [1 2]
#  [3 4]
#  [1 2]
#  [9 0]
#  [9 0]
#  [5 6]
#  [9 0]
#  [7 8]
#  [5 6]
#  [1 2]
#  [9 0]]
# 100%|██████████| 10/10 [00:11<00:00,  1.14s/it]
